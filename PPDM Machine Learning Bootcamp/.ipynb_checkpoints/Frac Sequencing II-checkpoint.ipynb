# %%
import numpy as np
import pandas as pd

from datetime import datetime
from datetime import timedelta

import os
import pymysql
import time
import datetime as dt
import re

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()

from pandas import set_option
set_option('display.max_columns',1000)
set_option('display.max_rows',1000)

host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')
conn = pymysql.connect(
    host="127.0.0.1",
    port=int(3306),
    user="lewis",
    passwd="BooBoo1oo",
    db="deeppurple",
    charset='utf8mb4')

# Select tables from SQL database.

production = pd.read_sql_query("SELECT * FROM production", conn)
location = pd.read_sql_query("SELECT * FROM location", conn)
completion = pd.read_sql_query("SELECT * FROM completion", conn)
bubble = pd.read_sql_query("SELECT * FROM bubble", conn)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9ac19886-5778-4b40-ac31-7fc84f42a3f0">Loading BokehJS ...</span>
#     </div>

# %%
# Read in drilling schedule data. This data is needed for Frac Date.

drilling = pd.read_excel('Hz_DP_Current.xlsx',sheet_name=1,header=3)
drilling = drilling.rename(index=str,columns={"Date.1":"Spud Date","Date.2":"Rig Release Date","Date.3":"Frac Date","Number":"Rig Number","Number.1":"Area Number"})

# Correct API to 10 digits.

drilling['API'] = drilling['API'].astype(str).str[:10]
drilling = drilling[['API','Official CQ Well Name','Rig Release Date','Frac Date','Prod Date','Bench','NRI']]
drilling = drilling.dropna(axis=0,how='any')

# Convert API data type back to 'int64'.

drilling['API'] = drilling['API'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-8069f3b0fefb> in <module>
#       1 # Read in drilling schedule data. This data is needed for Frac Date.
#       2
# ----> 3 drilling = pd.read_excel('Hz_DP_Current.xlsx',sheet_name=1,header=3)
#       4 drilling = drilling.rename(index=str,columns={"Date.1":"Spud Date","Date.2":"Rig Release Date","Date.3":"Frac Date","Number":"Rig Number","Number.1":"Area Number"})
#       5
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
bubble_mod = bubble[['API','Operator','Well','lbs proppant / ft_volume','Bbls of fluid / ft_volume',
                     'Formation','Lift Type','Number of stages / ft_volume','OIL_90','OIL_180','GAS_90',
                     'GAS_180','WATER_90','WATER_180','TOTAL FLUID_90','TOTAL FLUID_180']]
bubble_mod.sort_values(['Operator'],inplace=True)
bubble_mod.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#             API Operator               Well  lbs proppant / ft_volume  \
# 206  4238338500      AEP  Cope 107-108 01HS               1640.071130
# 211  4238339517      AEP    Cope 82-83 07HA               1940.937700
# 210  4238339525      AEP    Cope 82-81 07HA               2205.591773
# 207  4238338501      AEP  Cope 107-108 03HS               1630.864749
# 208  4238338853      AEP  Cope 107-108 16HS               1394.870029
#
#      Bbls of fluid / ft_volume Formation Lift Type  \
# 206                  27.167155         A      None
# 211                   0.000000      None      None
# 210                   0.000000         B      None
# ...

# %%
production.head()
# Out:
#    index         API        Date        Fluid     Fluid_cum         Gas  \
# 0      0  4231740293  2016-02-10  1775.900024   1775.900024    0.000000
# 1      1  4231740293  2016-02-11  2246.330059   4022.230083    0.000000
# 2      2  4231740293  2016-02-12  3034.160117   7056.390200   54.480000
# 3      3  4231740293  2016-02-13  2998.754999  10055.145199  198.509995
# 4      4  4231740293  2016-02-14  3795.774989  13850.920188  220.289993
#
#       Gas_cum     Oil  Oil_cum VorH        Water     Water_cum  \
# 0    0.000000    0.00     0.00    H  1775.900024   1775.900024
# 1    0.000000   27.77    27.77    H  2218.560059   3994.460083
# 2   54.480000  170.21   197.98    H  2854.870117   6849.330200
# 3  252.989994  263.67   461.65    H  2702.000000   9551.330200
# 4  473.279987  330.57   792.22    H  3428.489990  12979.820190
#
#             WellName lift_type  pressure
# 0  Bent Nail 36 #2HA      None       NaN
# 1  Bent Nail 36 #2HA      None       NaN
# ...

# %%
datetime.strptime?
